# %%
import pandas as pd

# %%
shelter = pd.read_csv("Animal_Shelter_Intake_and_Outcome.csv")
shelter
# Out:
#            Name   Type                    Breed           Color       Sex  \
# 0         RAZOR    DOG           BOSTON TERRIER     BLACK/WHITE  Neutered
# 1           NaN  OTHER                   PIGEON      GRAY/WHITE   Unknown
# 2           MAX    DOG            BORDER COLLIE  BLACK/TRICOLOR  Neutered
# 3           NaN    CAT              DOMESTIC LH      GRAY/WHITE    Spayed
# 4         PUDGY    DOG  CHIHUAHUA SH/SCHIPPERKE             TAN  Neutered
# ...         ...    ...                      ...             ...       ...
# 25003      BUBA    CAT              DOMESTIC SH      GRAY/WHITE  Neutered
# 25004  *JESSICA  OTHER                 AMERICAN     WHITE/BROWN    Spayed
# 25005    SHINER    DOG                 PIT BULL       TAN/WHITE  Neutered
# 25006   *NEWTON    DOG         CHIHUAHUA SH/MIX     BROWN/WHITE  Neutered
# 25007       NaN  OTHER                    SHEEP           WHITE    Female
#
#         Size Date Of Birth Impound Number Kennel Number Animal ID  ...  \
# ...

# %% [markdown]
# ### What are the top 10 breeds in the animal shelter?

# %% [markdown]
# ### What are the top 10 most common names?

# %% [markdown]
# ### What are the top 3 outcome type?

# %% [markdown]
# ### Evaluating yearly performance of the shelter based on (adoption rate, transfer rate, return to owner, euthanasia rate)
# rate = variable/total # of intakes
